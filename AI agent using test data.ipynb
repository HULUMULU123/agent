# %% [markdown]
# # Создание ИИ Агнета, который использует тестовые данные

# %%
# Подключаем LLM
import base64
import requests

url = "https://ngw.devices.sberbank.ru:9443/api/v2/oauth"

payload={
  'scope': 'GIGACHAT_API_PERS'
}
headers = {
  'Content-Type': 'application/x-www-form-urlencoded',
  'Accept': 'application/json',
  'RqUID': '2aba969c-a22a-4816-a652-393a756a96c1',
  'Authorization': 'Basic MDE5OWNlMTEtNmEyOC03OTBjLWJkOGMtZDdhYTI5OGI0MmZhOmRmOWYyOTg4LTVhMmEtNGZhNS04ZDdmLTNhMjE3ZDQ1ODY3Mg==',
}

response = requests.request("POST", url, headers=headers, data=payload, verify=False)

print(response.text)
# Out:
# /Users/stanislav/Documents/Work/bank_agent/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ngw.devices.sberbank.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {"access_token":"eyJjdHkiOiJqd3QiLCJlbmMiOiJBMjU2Q0JDLUhTNTEyIiwiYWxnIjoiUlNBLU9BRVAtMjU2In0.mm2wFsdZA-R1k2-8KiGp4Lqa42BRoNU8RuCiO7Ge_FF6CEMEBBIsSQUeaopcJjfY-Padk9w_12M4RCuUe6B71YM6nayCJP7f0wYnKKy_GDQJJo097E_FjFEpPktTGWJuMiiBaK4vxbH776E8PQTEm-fiEduzOuG5DZAa-yxwxfOSKH6KZPt1JFSTwmaetbqROcXJCxYAOP_jTyZpCqEisz5qOPNj6c-Vu7LxAQAtJ4D8Pb8Qa0feqLkuJKwzqoiDSOkYMwBmOCmSMlwmCiXAxHBfZzBnM6DgZijD4U6CtljTB0kXmBTbwqScEdAIP8LIjTfHqSgeP9nsRr4HCEGRsg.WFhJ5yQpQwVQ9JINMSHdeg.1tjoDBnxjCs5psMnhkDBvMwQS9m-xLkTv_8r9uUcQ1oI65uR15A-6HTxyxDRAaJSymvMadOj-MiSZy2w92i30H9gVErX8Yunqpd_IR15hUkJoT26g7auLLEzd2ZfLA4dkcjOEc0ut8Cv_MKIUhOX7yZabhBnuN9GMPw4SjZ1GJYXe_M79h0w5tjrMOoFOHEXKI7OjsF9H3EQtzk7w7iC7tT_Kdxbxfcn6N3MhIXfkOMbRQsCHcJAKgMLiOX02sc2crBCwSc2THguoCXZVyuLaRYlgPgWSoQ0jtiEYYuBxmBJ51vDZ-CllhafU3RcbD1sWPGZIaTr0unbEE2HYvTwf_240JxTsk4cR9e1WMXQOChR41ifmVvtLixlcX37mkmt1e97k66d-W9waaINcL5aplt_-6kECNhlysqCRopOKESrOUU0yCXaRmVHAtcO-6EPy6bzHwcRs17nWCMZQbyoxs3iYf7pcXiSg4vmNuOERRiD8Cbv4U4VM9a-Opf1moVZR3C-6LgGIDagknZQu17KlNzKQ8l-B9-HbfDbc8e2Uugq87CQQx9_NmDkW-zHJix0S_7jzVCfOpxgZ0heY0sigKruaP5QE559nIvhpSEPRmeU2GIHW7UQHdHYONYJ5axIU1dXDamebuOYFtK5zkwh9YVAaVwU0CLClPtjNQeSGDHgfXKmrCJ83rLS8_OY-gSSl5asp0d42brB04u2W0oTsNdVyCKhiEsJSX9ek7b1zKk.xz9Wg54JIL8lmDOFOB4I3fcNHO_SUJJg8RPR0jFtjNE","expires_at":1760429752835}

# %%
data = response.json()
access_token = data['access_token']
print(acсess_token)
# Out:
# eyJjdHkiOiJqd3QiLCJlbmMiOiJBMjU2Q0JDLUhTNTEyIiwiYWxnIjoiUlNBLU9BRVAtMjU2In0.OW7d0DsHIcCEuAXVT9etXPeX3cSo2vQNbDxtX2RMK0bnA54BtygHpeQyuusQhTMG5hEFatq2nQc_2Goll67PriKZhA1hgQX7cDD2kT9XIUdVU5q6Z-uH-GhVxQACxUNnEUQGk8IqchUHUl0abpinxB-zEnHteO-bcnkozdFu2dgaD-iIXf3rkAywUYM5BUJftMsOMDX1iZ85H2tpHryk0wXqkoxpOiLBLJbRNs8oJfl9jDwCHSDcGquzR45L9fOh8UgPQ-2UKjLT59ZzIYsaJ4Aw2IOEtmXqMp5L_mGzvMmOK4WycCQYF5_k4wuIT5UC0Fs_sRKJJm4F5OXrQMhBTw.JSEe5MBptPmhZackZ8jcEg.X7YQS76rQxx_FiVTMDKyxIakoKwRxUsU3QYEjdUM43lon3RpaPGCaGlKqev3Qdvsp61yo9qthpG5E7ThZFk7HHC6g5f00LfSOKUiMqyiml5v1HSOKH2JAmTp-j6EX4sRUkx0yp7dKMD58UKvjaPMxHrjakbpuIZLPTjoHcBdJWar71Rbg3VQUdQIJyuD902qtmcegyGvT_RtdqPazFJUyLF81_rX1MdzpBLW7sd8Mp8fdjMmPvEH8V3IjYJGObQfAS546ezXFYy-VxT5j2XakLLhDMqoHtR5KvSJD-MTOq_vkqbOM5KH8GLhmT0Uigy_ulAAKZ4Dv5eEav4VXJxvHDR-EN_ZSJLlsj5QgQV1bb6327NI47P63UgnqmwDKHJyiaiJ4kALQIAsg7QY7RZpRN5fITD8Fng_OF0M_0NcdRoyQRoJfdOSd_vVbhqqVUj1ZyZIYRbJzLxeCPjqQvLE95U-ERudVCRWLE3iWeZb-3k6aDLuAzCEMemhNXFt3jJsUbLOFTRGwUbAITEkrpivrYlVNp7Q4IqiEGCmcFIiFjm3s7K6amJXEflbKi0QwQfYa4gjtFfJcvPJlpA564J-Owqv-5vAMBZumdjRNNdk9Xxnrd2KoVWYxoPI8l_c439JYSBUW-6iJekCAAdx2Ls0n7hAHzOEFAR6iYwcRrwkF0hHVennqJgjz9FnTOEFI7bMNfc63HR5-JtGt2XHBKUp2k3lRkR1T2C6yU_MOd25-uM.aXFkeB1qSwWObB_G28orttwMw34oyZnAyjVIMSjt57Q

# %%
import pandas as pd
from ddgs import DDGS
from langchain_gigachat.chat_models import GigaChat
from langchain.agents import initialize_agent
from langchain.tools import tool
import os

# %%
# !pip install python-docx
# Out:
# Requirement already satisfied: python-docx in ./venv/lib/python3.13/site-packages (1.2.0)
# Requirement already satisfied: lxml>=3.1.0 in ./venv/lib/python3.13/site-packages (from python-docx) (6.0.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in ./venv/lib/python3.13/site-packages (from python-docx) (4.15.0)

# %%
from langchain.schema import HumanMessage, SystemMessage
from langchain.memory import ConversationBufferMemory
from docx import Document
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
llm = GigaChat(credentials='MDE5OWNlMTEtNmEyOC03OTBjLWJkOGMtZDdhYTI5OGI0MmZhOmRmOWYyOTg4LTVhMmEtNGZhNS04ZDdmLTNhMjE3ZDQ1ODY3Mg==', model="GigaChat-2", top_p=0, timeout=120, verify_ssl_certs=False,)

doc_path = "system_prompt.docx"  
doc = Document(doc_path)
system_prompt = "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# Создаём память
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

# Добавляем системный промпт в память один раз
memory.chat_memory.add_message(SystemMessage(content=system_prompt))

# Передаём системный промпт один раз
memory.chat_memory.add_message(SystemMessage(content=system_prompt))

# %%
import pandas as pd
import re
from sklearn.preprocessing import LabelEncoder
from langchain.tools import tool

# Функция для добавления колонок с юридической формой и LabelEncoding

def add_legal_form_columns(df, cols=["debit_name", "credit_name"]):
    legal_forms = [
        "ООО", "ИП", "АО", "ПАО", "ЗАО", "ОАО",
        "ГУП", "МУП", "ФГУП", "НКО", "АНО", "ТОО", "ОДО", "ЧУП", "КФХ",
        "ПК", "ПТ", "СПК", "СНТ", "ТСЖ", "ЖСК", "ОП", "НП", "ФП", "Ассоциация", "Союз"
    ]
    patterns = {form: re.compile(rf'\b{form}\b', re.IGNORECASE) for form in legal_forms}

    def detect_legal_form(text):
        cleaned = re.sub(r'[\"«»“”,.()*/]', ' ', str(text))
        tokens = [t.upper() for t in re.split(r'\s+', cleaned.strip()) if t]
        for form, pattern in patterns.items():
            if any(pattern.search(t) for t in tokens):
                return form
        return "Другое"

    for col in cols:
        new_col = f"{col}_type"
        df[new_col] = df[col].astype(str).fillna("").apply(detect_legal_form)
        # LabelEncoding для колонки с типом
        le = LabelEncoder()
        df[f"{new_col}_encoded"] = le.fit_transform(df[new_col])
    return df


# Функция для бинарного кодирования риска (OneHot для ключевых слов)

def onehot_risk_features(df):
    df["purpose"] = df["purpose"].astype(str).fillna("")
    risk_keywords = {
        "loan_related": ["займ", "договор займа", "возврат займа"],
        "unclear_transfer": ["взаиморасчёт", "перевод средств", "без договора", "перевод на карту"],
        "no_contract": ["оплата без договора", "прочие расходы", "личные нужды"],
        "crypto_activity": ["крипто", "биткоин", "usdt", "биржа", "coin", "crypto"],
        "foreign_payment": ["иностранный перевод", "swift", "валютный счёт", "экспорт"],
        "related_party_transfer": ["возврат займа", "займ физ. лицу", "передача активов"],
        "cash_out": ["пополнение", "наличные", "выдача наличных", "обналичивание"],
        "donation": ["благотворительность", "пожертвование"],
        "agent_fee": ["агентское вознаграждение", "комиссионное"],
        "service_payment": ["оплата услуг", "услуги по договору", "консультационные", "маркетинг"],
        "bonus_related": ["премия", "бонус", "вознаграждение"],
        "advance_payment": ["аванс", "предоплата", "частичная оплата"],
        "lease_payment": ["аренда", "лизинг", "субаренда"],
        "logistics": ["логистика", "транспорт", "перевозка"],
        "has_docs": ["оплата по договору", "счёт-фактура", "акт выполненных работ", "ттн"],
        "salary_related": ["зарплата", "заработная плата", "компенсация отпуска", "взносы"],
        "utilities": ["коммунальные услуги", "аренда офиса", "интернет", "телефон"],
        "tax_payment": ["налоги", "страховые взносы", "пфр", "фнс", "пенсионный фонд"],
        "supplier_payment": ["поставщик", "поставка", "товары", "материалы", "сырьё"],
        "internal_transfer": ["внутренний перевод", "между счетами организации"]
    }

    for col_name, keywords in risk_keywords.items():
        pattern = r'(' + '|'.join([re.escape(k.lower()) for k in keywords]) + r')'
        df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
    return df


# Функция для LabelEncoding risk

def encode_risk_label(df):
    le_risk = LabelEncoder()
    df['risk_encoded'] = le_risk.fit_transform(df['risk'].astype(str))
    return df


# Tool для агента

@tool("preprocess_data", description="Применяет все шаги предобработки: добавление legal_form с LabelEncoding, бинарное кодирование риска и LabelEncoding risk")
def preprocess_data(file_path: str):
    import os
    ext = os.path.splitext(file_path)[1].lower()
    if ext == ".csv":
        df = pd.read_csv(file_path)
    elif ext in [".xls", ".xlsx"]:
        df = pd.read_excel(file_path)
    else:
        raise ValueError("Неподдерживаемый формат файла. Используйте CSV или Excel.")

    # Применяем все функции
    df = add_legal_form_columns(df)
    df = onehot_risk_features(df)
    df = encode_risk_label(df)
    # Список нужных колонок
    risk_cols = [
        "loan_related", "unclear_transfer", "no_contract", "crypto_activity",
        "foreign_payment", "related_party_transfer", "cash_out", "donation",
        "agent_fee", "service_payment", "bonus_related", "advance_payment",
        "lease_payment", "logistics", "has_docs", "salary_related", "utilities",
        "tax_payment", "supplier_payment", "internal_transfer"
    ]
    final_cols = [
        "debit_name_type_encoded",
        "credit_name_type_encoded",
        "risk_encoded", "purpose"
    ] + risk_cols

    df_final = df[final_cols]
    return df_final.to_json(orient="records")

# %%
from typing import List, Dict
from langchain.tools import tool
import pandas as pd
import joblib
import json

@tool(
    "local_model_analysis",
    description="Применяет локальную ML модель и выдает численный коэффициент, который отражает степень риска модели"
)
def local_model_analysis(json_records: str):
    """
    Применяет локальную модель RandomForestRegressor к списку записей.
    
    records: список словарей (каждая запись — строка с признаками из preprocess_data)
    model_path: путь к локальной модели .pkl
    """
    model_path = "rf_reg_model.pkl"
    
    records = json.loads(json_records)
    # Преобразуем список словарей в DataFrame
    df = pd.DataFrame(records)

    # Загружаем модель
    rf_model = joblib.load(model_path)

    # Формируем фичи для модели (все колонки кроме purpose и risk_encoded)
    feature_cols = [col for col in df.columns if col not in ['risk_encoded', 'purpose']]
    X = df[feature_cols]

    # Предсказание
    y_pred = rf_model.predict(X)

    # Итоговый результат: purpose + ml_metric
    df_out = pd.DataFrame({
        "purpose": df["purpose"],
        "ml_metric": [round(val, 2) for val in y_pred]
    })

    # Возвращаем список словарей
    return df_out.to_json(orient="records")

# %%
tools = [preprocess_data, local_model_analysis]

agent = initialize_agent(
    tools=tools,
    llm=llm,
    agent="chat-zero-shot-react-description",  # ReAct: рассуждение + действия
    verbose=True
)

# %%
import pandas as pd

# Читаем исходный CSV
df = pd.read_csv('data/statement_main.csv')

# Берем случанйные 5 строк
df_5 = df.sample(50)


original_file = 'data/statement_main.csv'
new_file = original_file.replace('.csv', '_5.csv')

# Сохраняем новый CSV
df_5.to_csv(new_file, index=False)

print(f"Сохранено первые 5 строк в файл: {new_file}")
# Out:
# Сохранено первые 5 строк в файл: data/statement_main_5.csv

# %%
from langchain.schema import HumanMessage


excel_file = "data/statement_main_5.csv"  # ваш файл Excel
records = preprocess_data.func(excel_file)  # считываем и преобразуем данные

records = local_model_analysis.func(records)   # локальный анализ



results = []

if isinstance(records, str):
    records = json.loads(records)
print(records)   
for record in records:
    
    purpose = record["purpose"]
    ml_metric = record["ml_metric"]

    user_prompt = f"""
    Информация по одному платежу: 
    Назначение платежа: {purpose}
    Коэффициент риска модели: {ml_metric}
    """

    response = llm.invoke([
    SystemMessage(content=system_prompt),
    HumanMessage(content=user_prompt)
])
    

    print(f"\n Платёж: {purpose[:60]}...")
    print(f" Ответ модели:\n{result_text}\n")

    text = response.content if hasattr(response, "content") else response[0].content

    # Парсим основные колонки
    risk_match = re.search(r"\*\*Оценка риска:\*\*\s*(.*)", text)
    short_desc_match = re.search(r"- \*\*Краткая характеристика:\*\*\s*(.*)", text)
    reason_match = re.search(r"- \*\*Причины классификации:\*\*\s*(.*)", text)
    recommendations_match = re.search(r"- \*\*Рекомендации:\*\*\s*(.*)", text)

    results.append({
        "purpose": purpose,
        "ml_metric": ml_metric,
        "risk_level": risk_match.group(1).strip() if risk_match else "",
        "short_description": short_desc_match.group(1).strip() if short_desc_match else "",
        "reason": reason_match.group(1).strip() if reason_match else "",
        "recommendations": recommendations_match.group(1).strip() if recommendations_match else ""
    })

# Сохраняем результат в Excel
df_results = pd.DataFrame(results)
output_path = "data/statement_main_20_with_ai.xlsx"
df_results.to_excel(output_path, index=False)

print(f"\n Анализ завершён. Результаты сохранены в: {output_path}")
# Out:
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# /var/folders/hx/6vltr8z949358k44l1m6_b7m0000gn/T/ipykernel_1428/2022201780.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col_name] = df["purpose"].str.lower().str.contains(pattern, regex=True).astype(int)
# [{'purpose': 'Оплата электроэнергии по счёту №56917 от 18.08.2025', 'ml_metric': 1.47}, {'purpose': 'Перечисление НДС за сентября 2025, платежное поручение 1862', 'ml_metric': 1.42}, {'purpose': 'Выдан займ по договору займа №Z-1822 от 01.08.2025, срок возврата 22.12.2025', 'ml_metric': 2.0}, {'purpose': 'Разовый приход: оплата по счёту №21810, основание: погашение задолженности по устной договоренности', 'ml_metric': 1.47}, {'purpose': 'Возврат денежных средств по счёту №50635 от 10.08.2025', 'ml_metric': 1.47}, {'purpose': 'Выплата заработной платы за августа 2025 по ведомости №5608', 'ml_metric': 1.47}, {'purpose': 'Разовый перевод, основание: проведение расчетов по накладной', 'ml_metric': 0.69}, {'purpose': 'Разовый приход: оплата по счёту №50966, основание: погашение задолженности по устной договоренности', 'ml_metric': 1.47}, {'purpose': 'Оплата услуг по договору №US-1534 (Предоставление услуг), акт №93746', 'ml_metric': 1.65}, {'purpose': 'Оплата услуг по договору №US-9644 (Предоставление услуг), акт №28629', 'ml_metric': 1.65}, {'purpose': 'Оплата по договору поставки №1540 от 10.08.2025, счет №29320 от 01.08.2025, без НДС', 'ml_metric': 1.25}, {'purpose': 'Разовый перевод, основание: проведение расчетов по накладной', 'ml_metric': 1.47}, {'purpose': 'Оплата услуг по договору №US-1564 (Предоставление услуг), акт №68889', 'ml_metric': 1.75}, {'purpose': 'Оплата аренды офиса по договору №AR-6023 за августа 2025, счет №12130', 'ml_metric': 0.69}, {'purpose': 'Разовый приход: оплата по счёту №14233, основание: погашение задолженности по устной договоренности', 'ml_metric': 1.47}, {'purpose': 'Разовый перевод, основание: компенсация затрат по акту', 'ml_metric': 1.47}, {'purpose': 'Оплата по договору поставки №9689 от 23.08.2025 (покупка), счет-фактура №98435', 'ml_metric': 1.25}, {'purpose': 'Разовый перевод, основание: компенсация затрат по акту', 'ml_metric': 1.47}, {'purpose': 'Возврат по договору/кредиту, основание — корректировка, счет №46144', 'ml_metric': 1.47}, {'purpose': 'Выплата заработной платы за августа 2025 по ведомости №3102', 'ml_metric': 1.47}, {'purpose': 'Оплата по договору поставки №6101 от 13.08.2025 (покупка), счет-фактура №17677', 'ml_metric': 1.25}, {'purpose': 'Выдан займ по договору займа №Z-6713 от 12.09.2025, срок возврата 07.01.2026', 'ml_metric': 2.0}, {'purpose': 'Разовый приход: оплата по счёту №78196, основание: возврат аванса', 'ml_metric': 1.46}, {'purpose': 'Оплата по договору поставки №9659 от 17.09.2025 (покупка), счет-фактура №6077', 'ml_metric': 1.25}, {'purpose': 'Оплата по контракту №6310 от 10.08.2025, предоплата 50% по счёту №3956', 'ml_metric': 1.18}, {'purpose': 'Разовый перевод, основание: возврат аванса', 'ml_metric': 1.46}, {'purpose': 'Разовый приход: оплата по счёту №13180, основание: возврат аванса', 'ml_metric': 1.46}, {'purpose': 'Оплата услуг по договору №US-5291 от 29.09.2025, акт №29382 от 24.09.2025', 'ml_metric': 1.65}, {'purpose': 'Оплата по договору поставки №9676 от 21.08.2025 (покупка), счет-фактура №3438', 'ml_metric': 1.25}, {'purpose': 'Оплата услуг по договору №US-4663 (Предоставление услуг), акт №8333', 'ml_metric': 1.65}, {'purpose': 'Оплата по контракту №9494 от 08.08.2025, предоплата 50% по счёту №15771', 'ml_metric': 1.46}, {'purpose': 'Оплата по договору на поставку №9151, оплата по счету №91738 от 06.08.2025', 'ml_metric': 1.25}, {'purpose': 'Перечисление НДС за сентября 2025, платежное поручение 3227', 'ml_metric': 1.47}, {'purpose': 'Оплата услуг по договору №US-9124 (Предоставление услуг), акт №69914', 'ml_metric': 1.83}, {'purpose': 'Разовый перевод, основание: погашение задолженности по устной договоренности', 'ml_metric': 1.47}, {'purpose': 'Разовый перевод, основание: погашение задолженности по устной договоренности', 'ml_metric': 1.47}, {'purpose': 'Оплата электроэнергии по счёту №33935 от 07.08.2025', 'ml_metric': 1.47}, {'purpose': 'Выплата заработной платы за августа 2025 по ведомости №5987', 'ml_metric': 1.47}, {'purpose': 'Оплата по ко ...
#
#  Платёж: Оплата электроэнергии по счёту №56917 от 18.08.2025...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Перечисление НДС за сентября 2025, платежное поручение 1862...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Выдан займ по договору займа №Z-1822 от 01.08.2025, срок воз...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый приход: оплата по счёту №21810, основание: погашение...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Возврат денежных средств по счёту №50635 от 10.08.2025...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Выплата заработной платы за августа 2025 по ведомости №5608...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый перевод, основание: проведение расчетов по накладной...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый приход: оплата по счёту №50966, основание: погашение...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата услуг по договору №US-1534 (Предоставление услуг), ак...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата услуг по договору №US-9644 (Предоставление услуг), ак...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по договору поставки №1540 от 10.08.2025, счет №29320...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый перевод, основание: проведение расчетов по накладной...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата услуг по договору №US-1564 (Предоставление услуг), ак...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата аренды офиса по договору №AR-6023 за августа 2025, сч...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый приход: оплата по счёту №14233, основание: погашение...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый перевод, основание: компенсация затрат по акту...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по договору поставки №9689 от 23.08.2025 (покупка), с...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый перевод, основание: компенсация затрат по акту...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Возврат по договору/кредиту, основание — корректировка, счет...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Выплата заработной платы за августа 2025 по ведомости №3102...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по договору поставки №6101 от 13.08.2025 (покупка), с...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Выдан займ по договору займа №Z-6713 от 12.09.2025, срок воз...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый приход: оплата по счёту №78196, основание: возврат а...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по договору поставки №9659 от 17.09.2025 (покупка), с...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по контракту №6310 от 10.08.2025, предоплата 50% по с...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый перевод, основание: возврат аванса...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый приход: оплата по счёту №13180, основание: возврат а...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата услуг по договору №US-5291 от 29.09.2025, акт №29382 ...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по договору поставки №9676 от 21.08.2025 (покупка), с...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата услуг по договору №US-4663 (Предоставление услуг), ак...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по контракту №9494 от 08.08.2025, предоплата 50% по с...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по договору на поставку №9151, оплата по счету №91738...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Перечисление НДС за сентября 2025, платежное поручение 3227...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата услуг по договору №US-9124 (Предоставление услуг), ак...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый перевод, основание: погашение задолженности по устно...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый перевод, основание: погашение задолженности по устно...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата электроэнергии по счёту №33935 от 07.08.2025...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Выплата заработной платы за августа 2025 по ведомости №5987...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по контракту №5795 от 05.09.2025, предоплата 50% по с...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по договору на поставку №4878, оплата по счету №88718...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по договору поставки №6814 от 02.09.2025, счет №95776...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый перевод, основание: возврат аванса...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Выплата заработной платы за августа 2025 по ведомости №2323...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Перечисление НДС за августа 2025, платежное поручение 5022...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый перевод, основание: возврат аванса...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата услуг по договору №US-6286 (Предоставление услуг), ак...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по контракту №1969 от 20.09.2025, предоплата 50% по с...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Разовый перевод, основание: компенсация затрат по акту...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по договору поставки №648 от 04.08.2025, счет №83272 ...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Платёж: Оплата по контракту №6859 от 05.08.2025, предоплата 50% по с...
#  Ответ модели:
# - **Оценка риска:** желтый
# - **Краткая характеристика:** типичная хозяйственная операция с признаками средней степени подозрительности
# - **Причины классификации:** ml_metric выше среднего уровня, общее назначение платежа содержит общую формулировку ("электроэнергия"), хотя само по себе это обычная хозяйственная операция
# - **Рекомендации:** рекомендуется запросить копию счета №26667 от 03.09.2025 для подтверждения факта оказания услуги
#
#
#  Анализ завершён. Результаты сохранены в: data/statement_main_20_with_ai.xlsx
